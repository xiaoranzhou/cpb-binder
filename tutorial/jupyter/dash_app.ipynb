# %% [markdown]
# # GUI of CPlantBox
# This is an CPlantBox with GUI, it can be run on Binder.

# %%
from jupyter_dash import JupyterDash
from jupyterlab_dash import AppViewer
import dash
import dash_core_components as dcc
import dash_html_components as html

import pandas as pd
from dash.dependencies import Input, Output, State
from CPlantBox_PiafMunch import *

# %%
# Build App
# JupyterDash.infer_jupyter_proxy_config()
external_stylesheets = ['https://codepen.io/chriddyp/pen/bWLwgP.css']
app = JupyterDash(__name__, external_stylesheets=external_stylesheets)

# Create server variable with Flask server object for use with gunicorn
server = app.server



p = pb.Plant()
r1 = pb.RootRandomParameter(p)
r2 = pb.RootRandomParameter(p)
r3 = pb.RootRandomParameter(p)
r4 = pb.RootRandomParameter(p)
r5 = pb.RootRandomParameter(p)
r6 = pb.RootRandomParameter(p)
r7 = pb.RootRandomParameter(p)
r8 = pb.RootRandomParameter(p)
r9 = pb.RootRandomParameter(p)
root_params = [r1, r2, r3, r4, r5, r6, r7, r8, r9]


s1 = pb.StemRandomParameter(p)
s2 = pb.StemRandomParameter(p)
s3 = pb.StemRandomParameter(p)
s4 = pb.StemRandomParameter(p)
s5 = pb.StemRandomParameter(p)
s6 = pb.StemRandomParameter(p)
s7 = pb.StemRandomParameter(p)
s8 = pb.StemRandomParameter(p)
s9 = pb.StemRandomParameter(p)

stem_params = [s1, s2, s3, s4, s5, s6, s7, s8, s9]

l1 = pb.LeafRandomParameter(p)
l2 = pb.LeafRandomParameter(p)
l3 = pb.LeafRandomParameter(p)
l4 = pb.LeafRandomParameter(p)
l5 = pb.LeafRandomParameter(p)
l6 = pb.LeafRandomParameter(p)
l7 = pb.LeafRandomParameter(p)
l8 = pb.LeafRandomParameter(p)
l9 = pb.LeafRandomParameter(p)

leaf_params = [l1, l2, l3, l4, l5, l6, l7, l8, l9]



def transform_value(value):
    return 10 ** value
BACKGROUND = 'rgb(255, 255, 255)'
r_organ = -1
s_organ = -1
l_organ = -1

COLORSCALE = [ [0, "rgb(244,236,21)"], [0.3, "rgb(249,210,41)"], [0.4, "rgb(134,191,118)"],
                [0.5, "rgb(37,180,167)"], [0.65, "rgb(17,123,215)"], [1, "rgb(54,50,153)"] ]
app.scripts.config.serve_locally = False
app.title = 'CPlantBox' 

# ROOT_P = ()

app.layout = html.Div([ html.Div([
            html.Div('root organ add/remove', style={'color': 'orange', 'fontSize': 14}),
             
            dcc.Input(id='root-organ', type='number', min=1, max=9, step=1, value =0),
            dcc.RadioItems(id='root-radio'),
            
            html.Hr(),
            html.Button(id='update-r-param', n_clicks=0, children='update parameters'),
#             html.Button(id='copy-param', n_clicks=0, children='copy parameters'),
            dcc.Input(id = 'r-name', type = 'text', value='undefined', placeholder = '{}, {}, '.format('r-name', 'text', ) ),
            
            dcc.Input(id = 'r-subtype', type = 'number', value = '-1', placeholder = '{}, {}'.format('subType', 'number', )  ),
            
            html.Div(id='r-lb-display'),
            dcc.Input(id = 'r-lb', type = 'range', value = '-1' ),
            
            html.Div(id='r-la-display'),
            
            dcc.Input(id = 'r-la', type = 'range', value = '-1'  ),
            
            html.Div(id='r-lmax-display'),
            dcc.Input(id = 'r-lmax', type = 'range' , min=1, max=500, value = '-1'  ),
            
            html.Div(id='r-ln-display'),
            dcc.Input(id = 'r-ln', type = 'range' , value = '-1' ),
            
            html.Div(id='r-theta-display'),            
            dcc.Input(id = 'r-theta', type = 'range',min=0, max=2 , value = '0' ),

            
            html.Div(id='r-r-display'),
            dcc.Input(id = 'r-r', type = 'range', value = '1'   ),
            
            html.Div(id='r-a-display'),
            dcc.Input(id = 'r-a', type = 'range', value = '0.25', min= 0.01, max = 2   ),
            
            html.Div(id='r-dx-display'),
            dcc.Input(id = 'r-dx', type = 'range', min=0, max=10, value = '0.25' ),
            
            html.Div(id='r-tT-display'),
            dcc.Input(id = 'r-tT', type = 'range', min=0, max=2, step = 1, value = '0'  ),
            
            html.Div(id='r-tN-display'),
            dcc.Input(id = 'r-tN', type = 'range' , value = '0'),
            
            html.Div(id='r-tS-display'),
            dcc.Input(id = 'r-tS', type = 'range' , value = '0'),
            
            
            html.P('successor subtype',),
            html.Div(id='r-sN-display1'),
            html.Div([
                dcc.Input(id = 'r-successor_{}'.format(n), type = 'number', min=2, max=9, step = 1 , 
                          value = -1 ) for n in range(3)
            ]) ,
            html.P('successor emergence percentage',),
            html.Div(id='r-sN-display2'),
            html.Div([
                dcc.Input(id = 'r-successorP_{}'.format(n), type = 'number', min=0, max=1 ,  
                          value = -1) for n in range(3)
                
            ]) 
            
################################## stem @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@            
            
        ], className='two columns'),
        
        html.Div([ 
            html.Div('stem organ add/remove', style={'color': 'darkgreen', 'fontSize': 14}),
            dcc.Input(id='stem-organ', type='number', min=1, max=9, step=1, value =0),
            dcc.RadioItems(id='stem-radio'),
            html.Hr(),
            html.Button(id='update-s-param', n_clicks=0, children='update parameters'),
#             html.Button(id='copy-s-param', n_clicks=0, children='copy parameters'),
            dcc.Input(id = 's-name', type = 'text', value='undefined', placeholder = '{}, {}, '.format('s-name', 'text', ) ),
            
            dcc.Input(id = 's-subtype', type = 'number', value = '-1', placeholder = '{}, {}'.format('subType', 'number', )  ),
            
            html.Div(id='s-lb-display'),
            dcc.Input(id = 's-lb', type = 'range', value = '-1' ),
            
            html.Div(id='s-la-display'),
            
            dcc.Input(id = 's-la', type = 'range', value = '-1'  ),
            
            html.Div(id='s-lmax-display'),
            dcc.Input(id = 's-lmax', type = 'range' , min=1, max=500, value = '-1'  ),
            
            html.Div(id='s-ln-display'),
            dcc.Input(id = 's-ln', type = 'range' , value = '-1' ),
            
            html.Div(id='s-theta-display'),            
            dcc.Input(id = 's-theta', type = 'range',min=0, max=2 , value = '0' ),

            
            html.Div(id='s-s-display'),
            dcc.Input(id = 's-r', type = 'range', value = '1' , min= 0.01, max = 2  ),
            
            html.Div(id='s-a-display'),
            dcc.Input(id = 's-a', type = 'range', value = '0.25' , min= 0.01, max = 2  ),
            
            html.Div(id='s-dx-display'),
            dcc.Input(id = 's-dx', type = 'range', min=0, max=30, value = '0.25' ),
            
            html.Div(id='s-tT-display'),
            dcc.Input(id = 's-tT', type = 'range', min=2, max=4, step = 2, value = '4'  ),
            
            html.Div(id='s-tN-display'),
            dcc.Input(id = 's-tN', type = 'range' , value = '0', max = 10, min =0),
            
            html.Div(id='s-tS-display'),
            dcc.Input(id = 's-tS', type = 'range' , value = '0'),
            
            
            html.P('successor subtype',),
            html.Div(id='s-sN-display1'),
            html.Div([
                dcc.Input(id = 's-successor_{}'.format(n), type = 'number', min=2, max=9, step = 1 , 
                          value = -1 ) for n in range(3)
            ]) ,
            html.P('successor emergence percentage',),
            html.Div(id='s-sN-display2'),
            html.Div([
                dcc.Input(id = 's-successorP_{}'.format(n), type = 'number', min=0, max=1 ,  
                          value = -1) for n in range(3)
                
            ]) 
            
        ], className='two columns'),

                       

################################## leaf @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@            
        html.Div([
            html.Div('leaf organ add/remove', style={'color': 'lightgreen', 'fontSize': 14}),
            dcc.Input(id='leaf-organ', type='number', min=1, max=9, step=1, value =0),
            dcc.RadioItems(id='leaf-radio', value = 2),
            html.Hr(),
            html.Button(id='update-l-param', n_clicks=0, children='update parameters'),
#             html.Button(id='copy-l-param', n_clicks=0, children='copy parameters'),
            dcc.Input(id = 'l-name', type = 'text', value='undefined', placeholder = '{}, {}, '.format('l-name', 'text', ) ),
            
            dcc.Input(id = 'l-subtype', type = 'number', value = '-1', placeholder = '{}, {}'.format('subType', 'number', )  ),
            
            html.Div(id='l-lb-display'),
            dcc.Input(id = 'l-lb', type = 'range', value = '-1' ),
            
            html.Div(id='l-la-display'),
            
            dcc.Input(id = 'l-la', type = 'range', value = '-1'  ),
            
            html.Div(id='l-lmax-display'),
            dcc.Input(id = 'l-lmax', type = 'range' , min=1, max=500, value = '-1'  ),
            
            html.Div(id='l-ln-display'),
            dcc.Input(id = 'l-ln', type = 'range' , value = '-1' ),
            
            html.Div(id='l-theta-display'),            
            dcc.Input(id = 'l-theta', type = 'range',min=0, max=2 , value = '0' ),

            
            html.Div(id='l-l-display'),
            dcc.Input(id = 'l-r', type = 'range', value = '1'   ),
            
            html.Div(id='l-a-display'),
            dcc.Input(id = 'l-a', type = 'range', value = '0.25' ,  min=0, max=2,  ),
            
            html.Div(id='l-dx-display'),
            dcc.Input(id = 'l-dx', type = 'range', min=0, max=5, value = '0.25' ),
            
            html.Div(id='l-tT-display'),
            dcc.Input(id = 'l-tT', type = 'range', min=2, max=4, step = 2, value = '4'  ),
            
            html.Div(id='l-tN-display'),
            dcc.Input(id = 'l-tN', type = 'range' , min=0, max=20,step = 1, value = '0'),
            
            html.Div(id='l-tl-display'),
            dcc.Input(id = 'l-tS', type = 'range' ,min=0, max=5,  value = '0'),
            
            
            html.P('successor subtype',),
            html.Div(id='l-sN-display1'),
            html.Div([
                dcc.Input(id = 'l-successor_{}'.format(n), type = 'number', min=2, max=9, step = 1 , 
                          value = -1 ) for n in range(3)
            ]) ,
            html.P('successor emergence percentage',),
            html.Div(id='l-sN-display2'),
            html.Div([
                dcc.Input(id = 'l-successorP_{}'.format(n), type = 'number', min=0, max=1 ,  
                          value = -1) for n in range(3)
                
            ]) 
            
        ], className='two columns'),
        
        
   
    
    
    html.Div([
        dcc.Slider(id='growing-days', min=1, max=365, value =30, 
                  marks={
                      0: '0 day',
                      30: '30 days',
                      365: '365 days',
                  }),
        html.Button('Run the model', id='run_model'),
        dcc.Loading(
                    id="loading-2",
                    children=[html.Div(dcc.Graph(id='3d-graph', style={'height' : '90vh'}),
                                               
                                      )],
                    type="circle",
        )],className="six columns"),

 ])


################################## root @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@            

@app.callback(
    Output('root-radio', 'options'),
    [Input('root-organ', 'value'), Input('update-r-param', 'n_clicks')],
    [State('root-radio', 'value'), State('r-name', 'value'), State('r-subtype', 'value')]
)
def set_root_options(number, click,va, name, subtype):
    r_organ = va
    print("1st r_organ ",r_organ)
    if name == 'undefined':
        return [{'label': '{}, subType: {}'.format(organ.name,  organ.subType), 'value': i} 
                for i,organ in enumerate( root_params[:number])]
    else: 
        print("2nd r_organ ",r_organ)    
        root_params[va].name = name
        root_params[va].subType = int(subtype)
        return [{'label': '{}, subType: : {}'.format(organ.name,  organ.subType), 'value': i} 
                for i,organ in enumerate( root_params[:number])]

# root organ parameter setting
@app.callback(
    Output('r-lb-display', 'children'),
    [Input('r-lb', 'value')], [State('root-radio', 'value')])
def update_parameter(lb, r_organ):
    if r_organ > -1:
        print(r_organ)
        root_params[r_organ].lb = float(lb)
        return u'lb is modified to {}'.format(str(lb))
    else:
        print(r_organ)
        return u'you can change lb here'
    
@app.callback(
    Output('r-la-display', 'children'),
    [Input('r-la', 'value')], [State('root-radio', 'value')])
def update_parameter(la, r_organ):
    if r_organ > -1:
        root_params[r_organ].la = float(la)
        return u'la is modified to {}'.format(str(la))
    else:
        return u'you can change la here'

    
@app.callback(
    Output('r-lmax-display', 'children'),
    [Input('r-lmax', 'value')], [State('root-radio', 'value')])
def update_parameter(lmax, r_organ):
    if r_organ > -1:
        root_params[r_organ].lmax = float(lmax)
        return u'lmax is modified to {}'.format(lmax)
    else:
        return u'you can change lmax here'    

    
@app.callback(
    Output('r-ln-display', 'children'),
    [Input('r-ln', 'value')], [State('root-radio', 'value')])
def update_parameter(ln, r_organ):
    if r_organ > -1:
        root_params[r_organ].ln = float(ln)
        return u'ln is modified to {}'.format(str(ln))
    else:
        return u'you can change ln here' 

@app.callback(
    Output('r-theta-display', 'children'),
    [Input('r-theta', 'value')], [State('root-radio', 'value')])
def update_parameter(theta, r_organ):
    if r_organ > -1:
        root_params[r_organ].theta = float(theta)
        return u'theta is modified to {}'.format(str(theta))
    else:
        return u'you can change theta here' 

@app.callback(
    Output('r-r-display', 'children'),
    [Input('r-r', 'value')], [State('root-radio', 'value')])
def update_parameter(r, r_organ):
    if r_organ > -1:
        root_params[r_organ].r = float(r)
        return u'r is modified to {}'.format(str(r))
    else:
        return u'you can change r here' 

@app.callback(
    Output('r-a-display', 'children'),
    [Input('r-a', 'value')], [State('root-radio', 'value')])
def update_parameter(a, r_organ):
    if r_organ > -1:
        root_params[r_organ].a = float(a)
        return u'a is modified to {}'.format(str(a))
    else:
        return u'you can change a here' 

@app.callback(
    Output('r-dx-display', 'children'),
    [Input('r-dx', 'value')], [State('root-radio', 'value')])
def update_parameter(dx, r_organ):
    if r_organ > -1:
        root_params[r_organ].dx = float(dx)
        return u'dx is modified to {}'.format(str(dx))
    else:
        return u'you can change dx here'     

    
@app.callback(
    Output('r-tT-display', 'children'),
    [Input('r-tT', 'value')], [State('root-radio', 'value')])
def update_parameter(tT, r_organ):
    if r_organ > -1:
        root_params[r_organ].tropismT = int(tT)
        return u'tropismT is modified to {}'.format(str(root_params[r_organ].tropismT))
    else:
        return u'you can change tropismT here'   

    
    
@app.callback(
    Output('r-tN-display', 'children'),
    [Input('r-tN', 'value')], [State('root-radio', 'value')])
def update_parameter(tN, r_organ):
    if r_organ > -1:
        root_params[r_organ].tropismN = float(tN)
        return u'tropismN is modified to {}'.format(str(root_params[r_organ].tropismN))
    else:
        return u'you can change tropismN here'
    
    
    
@app.callback(
    Output('r-tS-display', 'children'),
    [Input('r-tS', 'value')], [State('root-radio', 'value')])
def update_parameter(tS, r_organ):
    if r_organ > -1:
        root_params[r_organ].tropismS = float(tS)
        return u'tropismS is modified to {}'.format(str(root_params[r_organ].tropismS))
    else:
        return u'you can change tropismS here'

@app.callback(
    Output('r-sN-display1', 'children'),
    [Input('r-successor_{}'.format(n), 'value' )for n in range(3)], [State('root-radio', 'value')])
def update_parameter(v1,v2,v3, r_organ):
    if r_organ > -1:
        l = []
        for val in [v1,v2,v3]: 
            if val >0:
                l.append(val) 
                root_params[r_organ].successor = l
            else: break
        return u'successor number is modified to {}'.format(l)
    else:
        return u'undefined'

@app.callback(
    Output('r-sN-display2', 'children'),
    [Input('r-successorP_{}'.format(n), 'value' )for n in range(3)],
    [State('root-radio', 'value')])
def update_parameter(v1,v2,v3, r_organ):
    if r_organ > -1:
        l = []
        for val in [v1,v2,v3]:
            if val >0:
                
                l.append(val) 
                root_params[r_organ].successorP = l
            else: break
        return u'successor percentage is modified to {}'.format(l)
    else:
        return u'undefined'

# @app.callback(
#     Output('root-radio', 'value'),
#     [Input('root-radio', 'options')])
# def set_root_options(op):      
#     print("2nd r_organ ",r_organ)
#     return r_organ

################################## stem @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@            

@app.callback(
    Output('stem-radio', 'options'),
    [Input('stem-organ', 'value'), Input('update-s-param', 'n_clicks')],
    [State('stem-radio', 'value'), State('s-name', 'value'), State('s-subtype', 'value')]
)
def set_stem_options(number, click,va, name, subtype):
    r_organ = va
    print("1st r_organ ",r_organ)
    if name == 'undefined':
        return [{'label': '{}, subType: {}'.format(organ.name,  organ.subType), 'value': i} 
                for i,organ in enumerate( stem_params[:number])]
    else: 
        print("2nd r_organ ",r_organ)    
        stem_params[va].name = name
        stem_params[va].subType = int(subtype)
        return [{'label': '{}, subType: {}'.format(organ.name,  organ.subType), 'value': i} 
                for i,organ in enumerate( stem_params[:number])]

# root organ parameter setting
@app.callback(
    Output('s-lb-display', 'children'),
    [Input('s-lb', 'value')], [State('stem-radio', 'value')])
def update_parameter(lb, r_organ):
    if r_organ > -1:
        print(r_organ)
        stem_params[r_organ].lb = float(lb)
        return u'lb is modified to {}'.format(str(lb))
    else:
        print(r_organ)
        return u'you can change lb here'
    
@app.callback(
    Output('s-la-display', 'children'),
    [Input('s-la', 'value')], [State('stem-radio', 'value')])
def update_parameter(la, r_organ):
    if r_organ > -1:
        stem_params[r_organ].la = float(la)
        return u'la is modified to {}'.format(str(la))
    else:
        return u'you can change la here'

    
@app.callback(
    Output('s-lmax-display', 'children'),
    [Input('s-lmax', 'value')], [State('stem-radio', 'value')])
def update_parameter(lmax, r_organ):
    if r_organ > -1:
        stem_params[r_organ].lmax = float(lmax)
        return u'lmax is modified to {}'.format(lmax)
    else:
        return u'you can change lmax here'    

    
@app.callback(
    Output('s-ln-display', 'children'),
    [Input('s-ln', 'value')], [State('stem-radio', 'value')])
def update_parameter(ln, r_organ):
    if r_organ > -1:
        stem_params[r_organ].ln = float(ln)
        return u'ln is modified to {}'.format(str(ln))
    else:
        return u'you can change ln here' 

@app.callback(
    Output('s-theta-display', 'children'),
    [Input('s-theta', 'value')], [State('stem-radio', 'value')])
def update_parameter(theta, r_organ):
    if r_organ > -1:
        stem_params[r_organ].theta = float(theta)
        return u'theta is modified to {}'.format(str(theta))
    else:
        return u'you can change theta here' 

@app.callback(
    Output('s-s-display', 'children'),
    [Input('s-r', 'value')], [State('stem-radio', 'value')])
def update_parameter(r, r_organ):
    if r_organ > -1:
        stem_params[r_organ].r = float(r)
        return u'r is modified to {}'.format(str(r))
    else:
        return u'you can change r here' 

@app.callback(
    Output('s-a-display', 'children'),
    [Input('s-a', 'value')], [State('stem-radio', 'value')])
def update_parameter(a, r_organ):
    if r_organ > -1:
        stem_params[r_organ].a = float(a)
        return u'a is modified to {}'.format(str(a))
    else:
        return u'you can change a here' 

@app.callback(
    Output('s-dx-display', 'children'),
    [Input('s-dx', 'value')], [State('stem-radio', 'value')])
def update_parameter(dx, r_organ):
    if r_organ > -1:
        stem_params[r_organ].dx = float(dx)
        return u'dx is modified to {}'.format(str(dx))
    else:
        return u'you can change dx here'     

    
@app.callback(
    Output('s-tT-display', 'children'),
    [Input('s-tT', 'value')], [State('stem-radio', 'value')])
def update_parameter(tT, r_organ):
    if r_organ > -1:
        stem_params[r_organ].tropismT = int(tT)
        return u'tropismT is modified to {}'.format(str(stem_params[r_organ].tropismT))
    else:
        return u'you can change tropismT here'   

    
    
@app.callback(
    Output('s-tN-display', 'children'),
    [Input('s-tN', 'value')], [State('stem-radio', 'value')])
def update_parameter(tN, r_organ):
    if r_organ > -1:
        stem_params[r_organ].tropismN = float(tN)
        return u'tropismN is modified to {}'.format(str(stem_params[r_organ].tropismN))
    else:
        return u'you can change tropismN here'
    
    
    
@app.callback(
    Output('s-tS-display', 'children'),
    [Input('s-tS', 'value')], [State('stem-radio', 'value')])
def update_parameter(tS, r_organ):
    if r_organ > -1:
        stem_params[r_organ].tropismS = float(tS)
        return u'tropismS is modified to {}'.format(str(stem_params[r_organ].tropismS))
    else:
        return u'you can change tropismS here'

@app.callback(
    Output('s-sN-display1', 'children'),
    [Input('s-successor_{}'.format(n), 'value' )for n in range(3)], [State('stem-radio', 'value')])
def update_parameter(v1,v2,v3, r_organ):
    if r_organ > -1:
        l = []
        for val in [v1,v2,v3]: 
            if val >0:
                l.append(val) 
                stem_params[r_organ].successor = l
            else: break
        return u'successor number is modified to {}'.format(l)
    else:
        return u'undefined'

@app.callback(
    Output('s-sN-display2', 'children'),
    [Input('s-successorP_{}'.format(n), 'value' )for n in range(3)],
    [State('stem-radio', 'value')])
def update_parameter(v1,v2,v3, r_organ):
    if r_organ > -1:
        l = []
        for val in [v1,v2,v3]:
            if val >0:
                
                l.append(val) 
                stem_params[r_organ].successorP = l
            else: break
        return u'successor percentage is modified to {}'.format(l)
    else:
        return u'undefined'


    
################################## leaf @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@            


# @app.callback(
#     Output('3d-graph', 'figure'),[Input('remove-root-organ', 'n_clicks')]
# )
# @app.callback(
#     Output('3d-graph', 'figure'),[Input('add-root-organ', 'n_clicks')]
# )
@app.callback(
    Output('leaf-radio', 'options'),
    [Input('leaf-organ', 'value'), Input('update-l-param', 'n_clicks')],
    [State('leaf-radio', 'value'), State('l-name', 'value'), State('l-subtype', 'value')]
)
def set_leaf_options(number, click,va, name, subtype):
    r_organ = va
    print("1st r_organ ",r_organ)
    if name == 'undefined':
        return [{'label': '{}, subType: {}'.format(organ.name,  organ.subType), 'value': i} 
                for i,organ in enumerate( leaf_params[:number])]
    else: 
        print("2nd r_organ ",r_organ)    
        leaf_params[va].name = name
        leaf_params[va].subType = int(subtype)
        return [{'label': '{}, subType: {}'.format(organ.name,  organ.subType), 'value': i} 
                for i,organ in enumerate( leaf_params[:number])]

# root organ parameter setting
@app.callback(
    Output('l-lb-display', 'children'),
    [Input('l-lb', 'value')], [State('leaf-radio', 'value')])
def update_parameter(lb, r_organ):
    if r_organ > -1:
        print(r_organ)
        leaf_params[r_organ].lb = float(lb)
        return u'lb is modified to {}'.format(str(lb))
    else:
        print(r_organ)
        return u'you can change lb here'
    
@app.callback(
    Output('l-la-display', 'children'),
    [Input('l-la', 'value')], [State('leaf-radio', 'value')])
def update_parameter(la, r_organ):
    if r_organ > -1:
        leaf_params[r_organ].la = float(la)
        return u'la is modified to {}'.format(str(la))
    else:
        return u'you can change la here'

    
@app.callback(
    Output('l-lmax-display', 'children'),
    [Input('l-lmax', 'value')], [State('leaf-radio', 'value')])
def update_parameter(lmax, r_organ):
    if r_organ > -1:
        leaf_params[r_organ].lmax = float(lmax)
        return u'lmax is modified to {}'.format(lmax)
    else:
        return u'you can change lmax here'    

    
@app.callback(
    Output('l-ln-display', 'children'),
    [Input('l-ln', 'value')], [State('leaf-radio', 'value')])
def update_parameter(ln, r_organ):
    if r_organ > -1:
        leaf_params[r_organ].ln = float(ln)
        return u'ln is modified to {}'.format(str(ln))
    else:
        return u'you can change ln here' 

@app.callback(
    Output('l-theta-display', 'children'),
    [Input('l-theta', 'value')], [State('leaf-radio', 'value')])
def update_parameter(theta, r_organ):
    if r_organ > -1:
        leaf_params[r_organ].theta = float(theta)
        return u'theta is modified to {}'.format(str(theta))
    else:
        return u'you can change theta here' 

@app.callback(
    Output('l-l-display', 'children'),
    [Input('l-r', 'value')], [State('leaf-radio', 'value')])
def update_parameter(r, r_organ):
    if r_organ > -1:
        leaf_params[r_organ].r = float(r)
        return u'r is modified to {}'.format(str(r))
    else:
        return u'you can change r here' 

@app.callback(
    Output('l-a-display', 'children'),
    [Input('l-a', 'value')], [State('leaf-radio', 'value')])
def update_parameter(a, r_organ):
    if r_organ > -1:
        leaf_params[r_organ].a = float(a)
        return u'a is modified to {}'.format(str(a))
    else:
        return u'you can change a here' 

@app.callback(
    Output('l-dx-display', 'children'),
    [Input('l-dx', 'value')], [State('leaf-radio', 'value')])
def update_parameter(dx, r_organ):
    if r_organ > -1:
        leaf_params[r_organ].dx = float(dx)
        return u'dx is modified to {}'.format(str(dx))
    else:
        return u'you can change dx here'     

    
@app.callback(
    Output('l-tT-display', 'children'),
    [Input('l-tT', 'value')], [State('leaf-radio', 'value')])
def update_parameter(tT, r_organ):
    if r_organ > -1:
        leaf_params[r_organ].tropismT = int(tT)
        return u'tropismT is modified to {}'.format(str(leaf_params[r_organ].tropismT))
    else:
        return u'you can change tropismT here'   

    
    
@app.callback(
    Output('l-tN-display', 'children'),
    [Input('l-tN', 'value')], [State('leaf-radio', 'value')])
def update_parameter(tN, r_organ):
    if r_organ > -1:
        leaf_params[r_organ].tropismN = float(tN)
        return u'tropismN is modified to {}'.format(str(leaf_params[r_organ].tropismN))
    else:
        return u'you can change tropismN here'
    
    
    
@app.callback(
    Output('l-tl-display', 'children'),
    [Input('l-tS', 'value')], [State('leaf-radio', 'value')])
def update_parameter(tS, r_organ):
    if r_organ > -1:
        leaf_params[r_organ].tropismS = float(tS)
        return u'tropismS is modified to {}'.format(str(leaf_params[r_organ].tropismS))
    else:
        return u'you can change tropismS here'

@app.callback(
    Output('l-sN-display1', 'children'),
    [Input('l-successor_{}'.format(n), 'value' )for n in range(3)], [State('leaf-radio', 'value')])
def update_parameter(v1,v2,v3, r_organ):
    if r_organ > -1:
        l = []
        for val in [v1,v2,v3]: 
            if val >0:
                l.append(val) 
                leaf_params[r_organ].successor = l
            else: break
        return u'successor number is modified to {}'.format(l)
    else:
        return u'undefined'

@app.callback(
    Output('l-sN-display2', 'children'),
    [Input('l-successorP_{}'.format(n), 'value' )for n in range(3)],
    [State('leaf-radio', 'value')])
def update_parameter(v1,v2,v3, r_organ):
    if r_organ > -1:
        l = []
        for val in [v1,v2,v3]:
            if val >0:
                
                l.append(val) 
                leaf_params[r_organ].successorP = l
            else: break
        return u'successor percentage is modified to {}'.format(l)
    else:
        return u'undefined'



@app.callback(
    Output('3d-graph', 'figure'),
    [Input('run_model', 'n_clicks')],
    [State('root-organ', 'value'), State('stem-organ', 'value'), State('leaf-organ', 'value'), State('growing-days', 'value')])
def update_figure(n_clicks1, rootorgan, stemorgan, leaforgan, time):
    

    
    srp = pb.SeedRandomParameter(p)  # with default values
    srp.seedPos = pb.Vector3d(0., 0., -3.)  # [cm] seed position
    srp.maxB = 0  # [-] number of basal roots (neglecting basal roots and shoot borne)
    srp.firstB = 0  # [day] first emergence of a basal root
    srp.delayB = 0  # [day] delay between the emergence of basal roots
    srp.maxTil = 0
    srp.nC = 0
    # srp.nZ = 0
    srp.nCs = 0
    p.setOrganRandomParameter(srp)
#     print("rootorgan",rootorgan)
    for i in range(rootorgan):
        p.setOrganRandomParameter(root_params[i])
    for i in range(stemorgan):
        p.setOrganRandomParameter(stem_params[i])
    for i in range(leaforgan):
        p.setOrganRandomParameter(leaf_params[i])
    #  Simulating the plant growth


    p.initialize(True)

    p.simulate(time)

    fig = visual_plant_l(p)
    return fig

# %%
# app.run_server()
app.run_server(debug = True)
# Out:
# Dash app running on http://127.0.0.1:8050/
# 1st r_organ  None
# 1st r_organ  None
# 1st r_organ  2
# 2
# 1st r_organ  None
# 1st r_organ  None
# 1st r_organ  2
# 2
# 1st r_organ  2
